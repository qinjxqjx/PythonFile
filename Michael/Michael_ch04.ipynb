# %%
data1=[6,7.5,8,0,1]

# %%
arry1=np.array(data1)
arry1
# Out:
# array([ 6. ,  7.5,  8. ,  0. ,  1. ])

# %%
arry1.shape
# Out:
# (5L,)

# %%
arry1.ndim
# Out:
# 1

# %%
arry1.dtype
# Out:
# dtype('float64')

# %%
a=np.identity(3)
b=np.ones_like(a)
b
# Out:
# array([[ 1.,  1.,  1.],
#        [ 1.,  1.,  1.],
#        [ 1.,  1.,  1.]])

# %%
arr1=np.array([1,2,3],dtype=np.float32)
arr1.dtype
# Out:
# dtype('float32')

# %%
 import matplotlib.pyplot as plt
x=np.linspace(-3,3,20)
plt.plot(x,np.sin(x))
plt.show()

# %%
from IPython.display import Latex
Latex(r"$\sqrt{x^2+y^2}$")
# Out:
# $\sqrt{x^2+y^2}$

# %%
from IPython.display import Image
#Image(url='http://ww1.sinaimg.cn/mw600/6a77a719jw1dyx581xf1cj.jpg')
Image(filename="googleSearch.jpg")
#-*该文件的目录为当前文件夹的目录*-

# %%
import numpy as np
import matplotlib.pyplot as plt
points=np.arange(-5,5,0.01)
xs,ys=np.meshgrid(points,points)
z=np.sqrt(xs**2+ys**2)
plt.imshow(z,cmap=plt.cm.gray)
plt.colorbar()
plt.title("Image plot of $\sqrt{x^2+y^2}$ for a grid of values")
plt.show()

# %%
arr=np.random.randn(7)*5
#np.modf(arr)
arr
# Out:
# array([  9.8336876 , -12.7176257 ,  -0.01582194,  -7.36238338,
#          6.40444924,   0.30846471,   8.69288879])

# %%
names=np.array(['aa','bb','vv','aa'])
# !type test.txt 
#-*该文件的目录为ipython的根目录*-
# Out:
# i am a python file

# %%
nsteps=1000
draws=np.random.randint(0,2,size=nsteps)
steps=np.where(draws>0,1,-1)
walk=steps.cumsum()
walk.min()
walk.max()
# Out:
# 13
